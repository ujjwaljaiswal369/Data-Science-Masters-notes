# %% [markdown]
# ## SMOTE(Synthetic Minority Oversampling Technique)
# ## SMOTE (Synthetic Minority Over-sampling Technique) is a technique used in machine learning to address imbalanced datasets where the minority class has significantly fewer instances than the majority class. SMOTE involves generating synthetic instances of the minority class by interpolating between existing instances.

# %%
from sklearn.datasets import make_classification 
import pandas as pd

# %%
x,y = make_classification(n_samples=1000, n_features=2,n_clusters_per_class=1, n_redundant=0, weights=[0.90], random_state=1)

# %%
df1=pd.DataFrame(x, columns=['f1', 'f2'])
df2=pd.DataFrame(y, columns=['target'])
final_df = pd.concat([df1, df2], axis=1)

# %%
final_df
# Out:
#            f1        f2  target
# 0    1.536830 -1.398694       1
# 1    1.551108  1.810329       0
# 2    1.293619  1.010946       0
# 3    1.119889  1.632518       0
# 4    1.042356  1.121529       0
# ..        ...       ...     ...
# 995  2.210439  2.006772       0
# 996  1.910941  2.011860       0
# 997 -0.556625 -0.159837       0
# 998  1.004999  0.936290       0
# 999  1.462110  1.144978       0
#
# [1000 rows x 3 columns]

# %%
final_df['target'].value_counts()
# Out:
# 0    894
# 1    106
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'], final_df['f2'], c=final_df['target'])

# %%
pip install imblearn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.6/235.6 kB 20.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
x,y = oversample.fit_resample(final_df[['f1', 'f2']], final_df['target'])

# %%
x.shape
# Out:
# (1788, 2)

# %%
y.shape
# Out:
# (1788,)

# %%
y[y==0].value_counts()
# Out:
# 0    894
# Name: target, dtype: int64

# %%
y[y==1].value_counts()
# Out:
# 1    894
# Name: target, dtype: int64

# %%
df1 = pd.DataFrame(x, columns= ['f1', 'f2'])
df2 = pd.DataFrame(y, columns =['target'])
smote_sample = pd.concat([df1, df2], axis=1)

# %%
smote_sample['target'].value_counts()
# Out:
# 1    894
# 0    894
# Name: target, dtype: int64

# %%
plt.scatter(smote_sample['f1'], smote_sample['f2'], c=smote_sample['target'])
