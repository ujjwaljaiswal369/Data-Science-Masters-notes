# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId',axis = 1,  inplace = True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.drop(2, inplace = True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0    PC 17599  71.2833   C85        C
# 3    female  35.0      1      0      113803  53.1000  C123        S
# 4      male  35.0      0      0      373450   8.0500   NaN        S
# 5      male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 886    male  27.0      0      0      211536  13.0000   NaN        S
# 887  female  19.0      0      0      112053  30.0000   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0      111369  30.0000  C148        C
# 890    male  32.0      0      0      370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
df.set_index('Name', inplace = True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0      1      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss. Margaret Edith                        19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"             NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
#                                                         Ticket     Fare Cabin  \
# Name
# Braund, Mr. Owen Harris                              A/5 21171   7.2500   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    PC 17599  71.2833   C85
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803  53.1000  C123
# Allen, Mr. William Henry                                373450   8.0500   NaN
# Moran, Mr. James                                        330877   8.4583   NaN
# ...                                                        ...      ...   ...
# Montvila, Rev. Juozas                                   211536  13.0000   NaN
# Graham, Miss. Margaret Edith                            112053  30.0000   B42
# Johnston, Miss. Catherine Helen "Carrie"            W./C. 6607  23.4500   NaN
# Behr, Mr. Karl Howell                                   111369  30.0000  C148
# Dooley, Mr. Patrick                                     370376   7.7500   NaN
#
#                                                    Embarked
# Name
# Braund, Mr. Owen Harris                                   S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...        C
# Futrelle, Mrs. Jacques Heath (Lily May Peel)              S
# Allen, Mr. William Henry                                  S
# Moran, Mr. James                                          Q
# ...                                                     ...
# Montvila, Rev. Juozas                                     S
# Graham, Miss. Margaret Edith                              S
# Johnston, Miss. Catherine Helen "Carrie"                  S
# Behr, Mr. Karl Howell                                     C
# Dooley, Mr. Patrick                                       Q
#
# [890 rows x 10 columns]

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0    PC 17599  71.2833   C85        C
# 2    female  35.0      1      0      113803  53.1000  C123        S
# 3      male  35.0      0      0      373450   8.0500   NaN        S
# 4      male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 885    male  27.0      0      0      211536  13.0000   NaN        S
# 886  female  19.0      0      0      112053  30.0000   B42        S
# 887  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0      111369  30.0000  C148        C
# 889    male  32.0      0      0      370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
dic = {'key1' : [1,2,3,4,5],
      'key2' : [6,7,8,9,0],
      'key3' : [11,22,33,44,55]}

# %%
pd.DataFrame(dic)
# Out:
#    key1  key2  key3
# 0     1     6    11
# 1     2     7    22
# 2     3     8    33
# 3     4     9    44
# 4     5     0    55

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0    PC 17599  71.2833   C85        C
# 2    female  35.0      1      0      113803  53.1000  C123        S
# 3      male  35.0      0      0      373450   8.0500   NaN        S
# 4      male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 885    male  27.0      0      0      211536  13.0000   NaN        S
# 886  female  19.0      0      0      112053  30.0000   B42        S
# 887  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0      111369  30.0000  C148        C
# 889    male  32.0      0      0      370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
df1 = pd.read_csv('d0c695bb-58f7-45bd-a300-ad39fe13c341.csv')

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna(inplace = True)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.fillna('blank', inplace = True)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0    PC 17599  71.2833   C85        C
# 2    female  35.0      1      0      113803  53.1000  C123        S
# 3      male  35.0      0      0      373450   8.0500   NaN        S
# 4      male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 885    male  27.0      0      0      211536  13.0000   NaN        S
# 886  female  19.0      0      0      112053  30.0000   B42        S
# 887  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0      111369  30.0000  C148        C
# 889    male  32.0      0      0      370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#      index                                               Name  Survived  \
# 0        0                            Braund, Mr. Owen Harris         0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2        2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 3        3                           Allen, Mr. William Henry         0
# 4        4                                   Moran, Mr. James         0
# ..     ...                                                ...       ...
# 885    885                              Montvila, Rev. Juozas         0
# 886    886                       Graham, Miss. Margaret Edith         1
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         0
# 888    888                              Behr, Mr. Karl Howell         1
# 889    889                                Dooley, Mr. Patrick         0
#
#      Pclass     Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0         3    male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1         1  female  38.0      1      0    PC 17599  71.2833   C85        C
# 2         1  female  35.0      1      0      113803  53.1000  C123        S
# 3         3    male  35.0      0      0      373450   8.0500   NaN        S
# 4         3    male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...     ...   ...    ...    ...         ...      ...   ...      ...
# 885       2    male  27.0      0      0      211536  13.0000   NaN        S
# 886       1  female  19.0      0      0      112053  30.0000   B42        S
# 887       3  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 888       1    male  26.0      0      0      111369  30.0000  C148        C
# 889       3    male  32.0      0      0      370376   7.7500   NaN        Q
#
# [890 rows x 12 columns]

# %%
g = df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_182/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#            index  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0         244315    1390  12985.50    304    181  12142.7199
# 1         151290     664   8193.67    162    159  16543.3044

# %%
g.mean()
# Out:
# /tmp/ipykernel_182/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#                index    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         445.018215  2.531876  30.626179  0.553734  0.329690  22.117887
# 1         443.665689  1.947214  28.351799  0.475073  0.466276  48.514089

# %%
g1 = df.groupby('Pclass')

# %%
g1

# %%
g1.sum()
# Out:
# /tmp/ipykernel_182/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#          index  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1        99274       136  7111.42     90     77  18177.4125
# 2        81688        87  5168.83     74     70   3801.8417
# 3       214643       118  8898.92    302    193   6706.7701

# %%
g1.mean()
# Out:
# /tmp/ipykernel_182/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#              index  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       459.601852  0.629630  38.233441  0.416667  0.356481  84.154687
# 2       443.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3       438.046939  0.240816  25.138192  0.616327  0.393878  13.687286

# %%
g1.count()
# Out:
#         index  Name  Survived  Sex  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# Pclass
# 1         216   216       216  216  186    216    216     216   216    176
# 2         184   184       184  184  173    184    184     184   184     16
# 3         490   490       490  490  354    490    490     490   490     12
#
#         Embarked
# Pclass
# 1            214
# 2            184
# 3            490

# %%
g1.max().T
# Out:
# /tmp/ipykernel_182/2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                           1                          2  \
# index                          888                        885
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# index                             889
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# Sex                              male
# Age                              74.0
# SibSp                               8
# Parch                               6
# Ticket                     W./C. 6609
# Fare                            69.55

# %%
g1.max().transpose()
# Out:
# /tmp/ipykernel_182/3907411846.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().transpose()
# Pclass                           1                          2  \
# index                          888                        885
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# index                             889
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# Sex                              male
# Age                              74.0
# SibSp                               8
# Parch                               6
# Ticket                     W./C. 6609
# Fare                            69.55

# %%
df
# Out:
#      index                                               Name  Survived  \
# 0        0                            Braund, Mr. Owen Harris         0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2        2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 3        3                           Allen, Mr. William Henry         0
# 4        4                                   Moran, Mr. James         0
# ..     ...                                                ...       ...
# 885    885                              Montvila, Rev. Juozas         0
# 886    886                       Graham, Miss. Margaret Edith         1
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         0
# 888    888                              Behr, Mr. Karl Howell         1
# 889    889                                Dooley, Mr. Patrick         0
#
#      Pclass     Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0         3    male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1         1  female  38.0      1      0    PC 17599  71.2833   C85        C
# 2         1  female  35.0      1      0      113803  53.1000  C123        S
# 3         3    male  35.0      0      0      373450   8.0500   NaN        S
# 4         3    male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...     ...   ...    ...    ...         ...      ...   ...      ...
# 885       2    male  27.0      0      0      211536  13.0000   NaN        S
# 886       1  female  19.0      0      0      112053  30.0000   B42        S
# 887       3  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 888       1    male  26.0      0      0      111369  30.0000  C148        C
# 889       3    male  32.0      0      0      370376   7.7500   NaN        Q
#
# [890 rows x 12 columns]

# %%
 df5 = df[['Name','Survived'	,'Pclass']][0:5]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df6 = df[['Name','Survived'	,'Pclass']][5:10]

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
pd.concat([df5,df6])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
df7 = pd.concat([df5, df6] , axis = 1)

# %%
df7.fillna('hari')
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1.0    1.0
# 3                           Allen, Mr. William Henry      0.0    3.0
# 4                                   Moran, Mr. James      0.0    3.0
# 5                                               hari     hari   hari
# 6                                               hari     hari   hari
# 7                                               hari     hari   hari
# 8                                               hari     hari   hari
# 9                                               hari     hari   hari
#
#                                                 Name Survived Pclass
# 0                                               hari     hari   hari
# 1                                               hari     hari   hari
# 2                                               hari     hari   hari
# 3                                               hari     hari   hari
# 4                                               hari     hari   hari
# 5                            McCarthy, Mr. Timothy J      0.0    1.0
# 6                     Palsson, Master. Gosta Leonard      0.0    3.0
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      1.0    3.0
# 8                Nasser, Mrs. Nicholas (Adele Achem)      1.0    2.0
# 9                    Sandstrom, Miss. Marguerite Rut      1.0    3.0

# %%
data1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2 = pd.DataFrame({'key1':[1,2,45,6,67],
                      'key4':[56,5,6,7,8],
                      'key5':[3,56,5,6,6]})

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(data1 , data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %%
pd.merge(data1 , data2, how = 'left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %%
pd.merge(data1 , data2, how = 'right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %%
pd.merge(data1 , data2, how = 'outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %%
pd.merge(data1 , data2, how = 'outer', on = 'key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %%
pd.merge(data1 , data2, how = 'cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# 21       6     8     6       2     5    56
# 22       6     8     6      45     6     5
# 23       6     8     6       6     7     6
# 24       6     8     6      67     8     6

# %%
data1,data2
# Out:
# (   key1  key2  key3
#  0     1     4     3
#  1     2     5     4
#  2     4     6     5
#  3     5     7     6
#  4     6     8     6,
#     key1  key4  key5
#  0     1    56     3
#  1     2     5    56
#  2    45     6     5
#  3     6     7     6
#  4    67     8     6)

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
data1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]}, index = ['a', 'b', 'c', 'd', 'e'])

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
data2 = pd.DataFrame({'key11':[1,2,45,6,67],
                      'key4':[56,5,6,7,8],
                      'key5':[3,56,5,6,6]}, index = ['a', 'b', 'e', 'f', 'g'])

# %%
data2
# Out:
#    key11  key4  key5
# a      1    56     3
# b      2     5    56
# e     45     6     5
# f      6     7     6
# g     67     8     6

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key4  key5
# a     1     4     3    1.0  56.0   3.0
# b     2     5     4    2.0   5.0  56.0
# c     4     6     5    NaN   NaN   NaN
# d     5     7     6    NaN   NaN   NaN
# e     6     8     6   45.0   6.0   5.0

# %%
data1.join(data2, how = 'right')
# Out:
#    key1  key2  key3  key11  key4  key5
# a   1.0   4.0   3.0      1    56     3
# b   2.0   5.0   4.0      2     5    56
# e   6.0   8.0   6.0     45     6     5
# f   NaN   NaN   NaN      6     7     6
# g   NaN   NaN   NaN     67     8     6

# %%
data1.join(data2, how = 'inner')
# Out:
#    key1  key2  key3  key11  key4  key5
# a     1     4     3      1    56     3
# b     2     5     4      2     5    56
# e     6     8     6     45     6     5

# %%
data1.join(data2, how = 'outer')
# Out:
#    key1  key2  key3  key11  key4  key5
# a   1.0   4.0   3.0    1.0  56.0   3.0
# b   2.0   5.0   4.0    2.0   5.0  56.0
# c   4.0   6.0   5.0    NaN   NaN   NaN
# d   5.0   7.0   6.0    NaN   NaN   NaN
# e   6.0   8.0   6.0   45.0   6.0   5.0
# f   NaN   NaN   NaN    6.0   7.0   6.0
# g   NaN   NaN   NaN   67.0   8.0   6.0

# %%
data1.join(data2, how = 'cross')
# Out:
#     key1  key2  key3  key11  key4  key5
# 0      1     4     3      1    56     3
# 1      1     4     3      2     5    56
# 2      1     4     3     45     6     5
# 3      1     4     3      6     7     6
# 4      1     4     3     67     8     6
# 5      2     5     4      1    56     3
# 6      2     5     4      2     5    56
# 7      2     5     4     45     6     5
# 8      2     5     4      6     7     6
# 9      2     5     4     67     8     6
# 10     4     6     5      1    56     3
# 11     4     6     5      2     5    56
# 12     4     6     5     45     6     5
# 13     4     6     5      6     7     6
# 14     4     6     5     67     8     6
# 15     5     7     6      1    56     3
# 16     5     7     6      2     5    56
# 17     5     7     6     45     6     5
# 18     5     7     6      6     7     6
# 19     5     7     6     67     8     6
# 20     6     8     6      1    56     3
# 21     6     8     6      2     5    56
# 22     6     8     6     45     6     5
# 23     6     8     6      6     7     6
# 24     6     8     6     67     8     6

# %%
df
# Out:
#      index                                               Name  Survived  \
# 0        0                            Braund, Mr. Owen Harris         0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2        2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 3        3                           Allen, Mr. William Henry         0
# 4        4                                   Moran, Mr. James         0
# ..     ...                                                ...       ...
# 885    885                              Montvila, Rev. Juozas         0
# 886    886                       Graham, Miss. Margaret Edith         1
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         0
# 888    888                              Behr, Mr. Karl Howell         1
# 889    889                                Dooley, Mr. Patrick         0
#
#      Pclass     Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0         3    male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1         1  female  38.0      1      0    PC 17599  71.2833   C85        C
# 2         1  female  35.0      1      0      113803  53.1000  C123        S
# 3         3    male  35.0      0      0      373450   8.0500   NaN        S
# 4         3    male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...     ...   ...    ...    ...         ...      ...   ...      ...
# 885       2    male  27.0      0      0      211536  13.0000   NaN        S
# 886       1  female  19.0      0      0      112053  30.0000   B42        S
# 887       3  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 888       1    male  26.0      0      0      111369  30.0000  C148        C
# 889       3    male  32.0      0      0      370376   7.7500   NaN        Q
#
# [890 rows x 12 columns]

# %%
df['INR'] = df['Fare'].apply(lambda x : x*89.33)

# %%
df['INR']
# Out:
# 0       647.642500
# 1      6367.737189
# 2      4743.423000
# 3       719.106500
# 4       755.579939
#           ...
# 885    1161.290000
# 886    2679.900000
# 887    2094.788500
# 888    2679.900000
# 889     692.307500
# Name: INR, Length: 890, dtype: float64

# %%
df
# Out:
#      index                                               Name  Survived  \
# 0        0                            Braund, Mr. Owen Harris         0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2        2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 3        3                           Allen, Mr. William Henry         0
# 4        4                                   Moran, Mr. James         0
# ..     ...                                                ...       ...
# 885    885                              Montvila, Rev. Juozas         0
# 886    886                       Graham, Miss. Margaret Edith         1
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         0
# 888    888                              Behr, Mr. Karl Howell         1
# 889    889                                Dooley, Mr. Patrick         0
#
#      Pclass     Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  \
# 0         3    male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1         1  female  38.0      1      0    PC 17599  71.2833   C85        C
# 2         1  female  35.0      1      0      113803  53.1000  C123        S
# 3         3    male  35.0      0      0      373450   8.0500   NaN        S
# 4         3    male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...     ...   ...    ...    ...         ...      ...   ...      ...
# 885       2    male  27.0      0      0      211536  13.0000   NaN        S
# 886       1  female  19.0      0      0      112053  30.0000   B42        S
# 887       3  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 888       1    male  26.0      0      0      111369  30.0000  C148        C
# 889       3    male  32.0      0      0      370376   7.7500   NaN        Q
#
#              INR
# 0     647.642500
# 1    6367.737189
# 2    4743.423000
# 3     719.106500
# 4     755.579939
# ..           ...
# 885  1161.290000
# 886  2679.900000
# 887  2094.788500
# 888  2679.900000
# 889   692.307500
#
# [890 rows x 13 columns]

# %%
df['Name_no.'] = df['Name'].apply(len)

# %%
df[['Name_no.']].head()
# Out:
#    Name_no.
# 0        23
# 1        51
# 2        44
# 3        24
# 4        16

# %%
df
# Out:
#      index                                               Name  Survived  \
# 0        0                            Braund, Mr. Owen Harris         0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2        2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 3        3                           Allen, Mr. William Henry         0
# 4        4                                   Moran, Mr. James         0
# ..     ...                                                ...       ...
# 885    885                              Montvila, Rev. Juozas         0
# 886    886                       Graham, Miss. Margaret Edith         1
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         0
# 888    888                              Behr, Mr. Karl Howell         1
# 889    889                                Dooley, Mr. Patrick         0
#
#      Pclass     Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  \
# 0         3    male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1         1  female  38.0      1      0    PC 17599  71.2833   C85        C
# 2         1  female  35.0      1      0      113803  53.1000  C123        S
# 3         3    male  35.0      0      0      373450   8.0500   NaN        S
# 4         3    male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...     ...   ...    ...    ...         ...      ...   ...      ...
# 885       2    male  27.0      0      0      211536  13.0000   NaN        S
# 886       1  female  19.0      0      0      112053  30.0000   B42        S
# 887       3  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 888       1    male  26.0      0      0      111369  30.0000  C148        C
# 889       3    male  32.0      0      0      370376   7.7500   NaN        Q
#
#              INR  Name_no.
# 0     647.642500        23
# 1    6367.737189        51
# 2    4743.423000        44
# 3     719.106500        24
# 4     755.579939        16
# ..           ...       ...
# 885  1161.290000        21
# 886  2679.900000        28
# 887  2094.788500        40
# 888  2679.900000        21
# 889   692.307500        19
#
# [890 rows x 14 columns]

# %%
def car_fare(x):
    if x < 10 :
        return 'cheap'
    elif x >= 10 and x <= 20 :
        return 'Mid'
    else:
        return 'High'

# %%
df['cat_fare'] = df['Fare'].apply(car_fare)

# %%
df['cat_fare']
# Out:
# 0      cheap
# 1       High
# 2       High
# 3      cheap
# 4      cheap
#        ...
# 885      Mid
# 886     High
# 887     High
# 888     High
# 889    cheap
# Name: cat_fare, Length: 890, dtype: object

# %%
df.head()
# Out:
#    index                                               Name  Survived  Pclass  \
# 0      0                            Braund, Mr. Owen Harris         0       3
# 1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2      2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3      3                           Allen, Mr. William Henry         0       3
# 4      4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked          INR  \
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S   647.642500
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C  6367.737189
# 2  female  35.0      1      0     113803  53.1000  C123        S  4743.423000
# 3    male  35.0      0      0     373450   8.0500   NaN        S   719.106500
# 4    male   NaN      0      0     330877   8.4583   NaN        Q   755.579939
#
#    Name_no. cat_fare
# 0        23    cheap
# 1        51     High
# 2        44     High
# 3        24    cheap
# 4        16    cheap
